# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np  
# Assuming the result path is stored in a variable called result_path
result_path = './result/IL/training/1/'

file_list = os.listdir(result_path)

loss_values = np.array([])
for file_name in file_list:
    if file_name.endswith('.csv'):
        file = result_path + file_name
        data = pd.read_csv(file)
        loss_values = np.append(loss_values, data['loss'].values)
print(loss_values)
# Plot the loss values
plt.figure(figsize=(15, 6))
plt.plot(loss_values, label='Loss')
plt.xlabel('Backpropagation Iteration')
plt.ylabel('Loss')
plt.title('Loss Value Plot')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/columbia/roamlab/vibecheck/.conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'loss'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 15
#      13         file = result_path + file_name
#      14         data = pd.read_csv(file)
# ---> 15         loss_values = np.append(loss_values, data['loss'].values)
#      16 print(loss_values)
#      17 # Plot the loss values
#
# File ~/Desktop/columbia/roamlab/vibecheck/.conda/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Desktop/columbia/roamlab/vibecheck/.conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'loss'

# %%
result_path = './result/IL/training/1/'

file_list = os.listdir(result_path)

length = np.array([])
for file_name in file_list:
    if file_name.endswith('.csv'):
        file = result_path + file_name
        data = pd.read_csv(file)
        length = np.append(length, len(data))
print(length)
# Plot the loss values
plt.figure(figsize=(10, 6))
plt.plot(length, label='length')
plt.xlabel('Epoch')
plt.ylabel('length ')
plt.title('length for each epoch')
plt.legend()
plt.show()
# Out:
# [18. 28. 49. ... 80. 61. 32.]

# %%
result_path = './result/Jan_21_random_init2_longer/test/'

file_list = os.listdir(result_path)

length = np.array([])
for file_name in file_list:
    if file_name.endswith('.csv'):
        file = result_path + file_name
        data = pd.read_csv(file)
        
        length = np.append(length, len(data))
print(length)
# Plot the loss values
plt.figure(figsize=(10, 6))
plt.plot(length, label='length')
plt.xlabel('Epoch')
plt.ylabel('length ')
plt.title('length for each epoch')
plt.legend()
plt.show()
# Out:
# [50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 30. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.  1. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 21. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 22. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 13. 50. 50. 50. 50. 50. 50. 50. 30. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 48. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 35. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 17. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 23. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 50. 27. 50. 50. 50. 50. 50. 50.
#  50. 50. 50. 50. 50. 50. 50. 50. 50. 50.]

# %%
result_path = './result/IL/training/1/'

file_list = os.listdir(result_path)

rewards = np.array([])
for file_name in file_list:
    if file_name.endswith('.csv'):
        file = result_path + file_name
        data = pd.read_csv(file)
        
        rewards = np.append(rewards, data.iloc[len(data)-1]['tot_reward'])
print(rewards)
# Plot the loss values
plt.figure(figsize=(10, 6))
plt.plot(rewards, label='rewards')
plt.xlabel('Epoch')
plt.ylabel('rewards ')
plt.title('rewards for each epoch')
plt.legend()
plt.show()
# Out:
# [27. 37. 58. ... 89. 70. 41.]
